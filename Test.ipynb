# %%
1+1
# Out:
# 2

# %%
4561
1563
156
# Out:
# 156

# %%
456+456
# Out:
# 912

# %%
5456+845
# Out:
# 6301

# %% [markdown]
# # THEWORLDSAVIOUR

# %%
#theworldsaviour

# %% [markdown]
# #CHAMPION

# %% [markdown]
# ![1.JPG](attachment:1.JPG)
